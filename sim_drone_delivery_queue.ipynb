# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import heapq
from dataclasses import dataclass
from typing import List, Dict, Tuple, Optional
from enum import Enum

# Set style for better looking plots
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# %%
class EventType(Enum):
    ARRIVAL = "arrival"
    SERVICE_COMPLETION = "service_completion"
    ABANDON = "abandon"
    CHARGING_COMPLETION = "charging_completion"

@dataclass
class Event:
    time: float
    event_type: EventType
    customer_id: Optional[int] = None
    server_id: Optional[int] = None
    
    def __lt__(self, other):
        return self.time < other.time

@dataclass
class Customer:
    id: int
    arrival_time: float
    service_time: float
    patience_time: float
    
    # Results to be filled during simulation
    queue_length_on_arrival: int = 0
    servers_available_on_arrival: int = 0
    servers_occupied_on_arrival: int = 0  # NEW: servers busy serving customers
    servers_charging_on_arrival: int = 0  # NEW: servers in charging state
    system_size_on_arrival: int = 0  # Total customers in system
    wait_time: float = 0.0
    service_start_time: float = 0.0
    departure_time: float = 0.0
    charging_time: float = 0.0  # Time spent in charging (if applicable)
    abandoned: bool = False

    def get_server_state_summary(self):
        """Get a summary of server states at arrival"""
        total = self.servers_available_on_arrival + self.servers_occupied_on_arrival + self.servers_charging_on_arrival
        return {
            'available': self.servers_available_on_arrival,
            'occupied': self.servers_occupied_on_arrival,
            'charging': self.servers_charging_on_arrival,
            'total': total
        }

class QueueSimulation:
    def __init__(self, num_customers: int, lambda_rate: float, mu_rate: float, 
                 theta_rate: float, num_servers: int, p_charge: float = 0.0, 
                 gamma_rate: float = 1.0, charging_distribution: str = 'exponential',random_seed: int = 2221):
        """
        Initialize queue simulation parameters
        
        Args:
            num_customers: Fixed number of customers to simulate
            lambda_rate: Arrival rate (λ)
            mu_rate: Service rate (μ)
            theta_rate: Abandonment rate (θ)
            num_servers: Total number of servers (c)
            p_charge: Probability of going to charge after service (p)
            gamma_rate: Charging completion rate (γ)
            random_seed: Random seed for reproducibility
        """
        self.num_customers = num_customers
        self.lambda_rate = lambda_rate
        self.mu_rate = mu_rate
        self.theta_rate = theta_rate
        self.num_servers = num_servers
        self.p_charge = p_charge
        self.gamma_rate = gamma_rate
        
        np.random.seed(random_seed)
        
        # Generate all random variables upfront
        self.customers = self._generate_customers()

        # Pre-generate charging decisions for server completions
        # We need more than num_customers because servers can complete multiple services
        max_service_completions = num_customers * 3  # Conservative estimate
        self.charging_decisions = np.random.binomial(1, self.p_charge, max_service_completions)
        #print(self.charging_decisions)
        if charging_distribution == 'exponential':
            self.charging_times = np.random.exponential(1/self.gamma_rate, max_service_completions)
        elif charging_distribution == 'constant':
            self.charging_times = np.ones(max_service_completions) * (1/self.gamma_rate)  # Fixed charging time for simplicity 
        elif charging_distribution == 'uniform':
            self.charging_times = np.random.uniform(0, 2/self.gamma_rate, max_service_completions) #need to fix this
        else:
            raise ValueError(f"Unknown charging distribution: {charging_distribution}")
        #print(self.charging_times)
        self.charging_decision_index = 0
        
    def _generate_customers(self) -> List[Customer]:
        """Generate all customers with their random attributes"""
        customers = []
        
        # Generate inter-arrival times (exponential)
        inter_arrivals = np.random.exponential(1/self.lambda_rate, self.num_customers)
        arrival_times = np.cumsum(inter_arrivals)
        
        # Generate service times (exponential)
        service_times = np.random.exponential(1/self.mu_rate, self.num_customers)
        
        # Generate patience times (exponential)
        patience_times = np.random.exponential(1/self.theta_rate, self.num_customers)
        
        
        for i in range(self.num_customers):
            customer = Customer(
                id=i,
                arrival_time=arrival_times[i],
                service_time=service_times[i],
                patience_time=patience_times[i]
            )
            customers.append(customer)
            
        return customers
    
    def simulate_erlang_a(self) -> List[Customer]:
        """Simulate Erlang-A queue (no charging)"""
        # Initialize state
        event_queue = []
        queue = []  # Waiting customers
        servers = [None] * self.num_servers  # None means idle, customer_id means busy
        current_time = 0.0
        
        # Schedule all arrivals
        for customer in self.customers:
            heapq.heappush(event_queue, Event(customer.arrival_time, EventType.ARRIVAL, customer.id))
        
        # Process events
        while event_queue:
            event = heapq.heappop(event_queue)
            current_time = event.time
            
            if event.event_type == EventType.ARRIVAL:
                self._handle_arrival_erlang_a(event, queue, servers, event_queue)
            elif event.event_type == EventType.SERVICE_COMPLETION:
                self._handle_service_completion_erlang_a(event, queue, servers, event_queue)
            elif event.event_type == EventType.ABANDON:
                self._handle_abandon(event, queue)
        
        return self.customers
    
    def simulate_erlang_s(self) -> List[Customer]:
        """Simulate Erlang-S* queue (with charging)"""
        # Initialize state
        event_queue = []
        queue = []  # Waiting customers
        active_servers = list(range(self.num_servers))  # All servers start active
        charging_servers = []  # Servers in charging state
        server_assignments = {}  # server_id -> customer_id
        current_time = 0.0
        
        #print(f"DEBUG: Starting simulation with {self.num_servers} servers")
        #print(f"DEBUG: Initial active_servers: {active_servers}")
        
        # Schedule all arrivals
        for customer in self.customers:
            heapq.heappush(event_queue, Event(customer.arrival_time, EventType.ARRIVAL, customer.id))
        
        # Process events
        while event_queue:
            event = heapq.heappop(event_queue)
            current_time = event.time
            
            if event.event_type == EventType.ARRIVAL:
                self._handle_arrival_erlang_s(event, queue, active_servers, server_assignments, event_queue, charging_servers)
            elif event.event_type == EventType.SERVICE_COMPLETION:
                self._handle_service_completion_erlang_s(event, queue, active_servers, charging_servers, 
                                                    server_assignments, event_queue)
            elif event.event_type == EventType.ABANDON:
                self._handle_abandon(event, queue)
            elif event.event_type == EventType.CHARGING_COMPLETION:
                # Pass all necessary parameters for serving waiting customers
                self._handle_charging_completion(event, active_servers, charging_servers, 
                                            queue, server_assignments, event_queue)
        
        #print(f"DEBUG: Final state - active: {len(active_servers)}, charging: {len(charging_servers)}, occupied: {len(server_assignments)}")
        return self.customers

    # Update the arrival handler to accept charging_servers
    def _handle_arrival_erlang_s(self, event, queue, active_servers, server_assignments, event_queue, charging_servers):
        customer = self.customers[event.customer_id]
        customer.queue_length_on_arrival = len(queue)
        
        # Track server states for Erlang-S*
        available_servers = len(active_servers)
        occupied_servers = len(server_assignments)
        charging_servers_count = len(charging_servers)
        
        customer.servers_available_on_arrival = available_servers
        customer.servers_occupied_on_arrival = occupied_servers
        customer.servers_charging_on_arrival = charging_servers_count
        
        # Verify server count consistency
        total_tracked = available_servers + occupied_servers + charging_servers_count
        if total_tracked != self.num_servers:
            print(f"DEBUG WARNING: Server count mismatch at time {event.time:.3f}")
            print(f"  Available: {available_servers}, Occupied: {occupied_servers}, Charging: {charging_servers_count}")
            print(f"  Total: {total_tracked}, Expected: {self.num_servers}")
        
        # Calculate total customers in system (queue + being served)
        customers_being_served = occupied_servers
        customer.system_size_on_arrival = len(queue) + customers_being_served
        
        if active_servers:
            # Start service immediately
            server_id = active_servers.pop(0)
            server_assignments[server_id] = customer.id
            customer.service_start_time = event.time
            customer.wait_time = 0.0
            
            # Schedule service completion
            completion_time = event.time + customer.service_time
            heapq.heappush(event_queue, Event(completion_time, EventType.SERVICE_COMPLETION, 
                                            customer.id, server_id))
        else:
            # Join queue and schedule abandonment
            queue.append(customer.id)
            abandon_time = event.time + customer.patience_time
            heapq.heappush(event_queue, Event(abandon_time, EventType.ABANDON, customer.id))
        
    def _handle_arrival_erlang_a(self, event, queue, servers, event_queue):
        customer = self.customers[event.customer_id]
        customer.queue_length_on_arrival = len(queue)
        
        # Track server states for Erlang-A
        available_servers = sum(1 for s in servers if s is None)
        occupied_servers = sum(1 for s in servers if s is not None)
        
        customer.servers_available_on_arrival = available_servers
        customer.servers_occupied_on_arrival = occupied_servers
        customer.servers_charging_on_arrival = 0  # No charging in Erlang-A
        
        # Calculate total customers in system (queue + being served)
        customers_being_served = occupied_servers
        customer.system_size_on_arrival = len(queue) + customers_being_served
        
        # Check if server is available
        available_server = None
        for i, server in enumerate(servers):
            if server is None:
                available_server = i
                break
        
        if available_server is not None:
            # Start service immediately
            servers[available_server] = customer.id
            customer.service_start_time = event.time
            customer.wait_time = 0.0
            
            # Schedule service completion
            completion_time = event.time + customer.service_time
            heapq.heappush(event_queue, Event(completion_time, EventType.SERVICE_COMPLETION, 
                                            customer.id, available_server))
        else:
            # Join queue and schedule abandonment
            queue.append(customer.id)
            abandon_time = event.time + customer.patience_time
            heapq.heappush(event_queue, Event(abandon_time, EventType.ABANDON, customer.id))

    def _handle_charging_completion(self, event, active_servers, charging_servers, queue=None, server_assignments=None, event_queue=None):
        """Handle server charging completion - move server back to active and serve waiting customers"""
        server_id = event.server_id
        if server_id in charging_servers:
            charging_servers.remove(server_id)
            
            # Check if there are waiting customers in queue
            if queue and len(queue) > 0 and server_assignments is not None and event_queue is not None:
                # Immediately serve next customer instead of going to active list
                next_customer_id = queue.pop(0)
                next_customer = self.customers[next_customer_id]
                
                # Assign server to customer
                server_assignments[server_id] = next_customer_id
                next_customer.service_start_time = event.time
                next_customer.wait_time = event.time - next_customer.arrival_time
                
                # Schedule service completion
                completion_time = event.time + next_customer.service_time
                heapq.heappush(event_queue, Event(completion_time, EventType.SERVICE_COMPLETION, 
                                                next_customer_id, server_id))
                
                #print(f"DEBUG: Server {server_id} finished charging at time {event.time:.3f} and immediately serves customer {next_customer_id}")
            else:
                # No waiting customers, add to active servers
                active_servers.append(server_id)
                #print(f"DEBUG: Server {server_id} finished charging at time {event.time:.3f} and becomes available")
            
            #print(f"DEBUG: Active servers now: {active_servers}")
            #print(f"DEBUG: Charging servers now: {charging_servers}")
        else:
            print(f"DEBUG: ERROR - Server {server_id} not found in charging_servers at time {event.time:.3f}")
            print(f"DEBUG: Current charging_servers: {charging_servers}")
            print(f"DEBUG: Current active_servers: {active_servers}")

    
    def _handle_service_completion_erlang_a(self, event, queue, servers, event_queue):
        customer = self.customers[event.customer_id]
        customer.departure_time = event.time
        servers[event.server_id] = None
        
        # Check if there's a waiting customer
        if queue:
            next_customer_id = queue.pop(0)
            next_customer = self.customers[next_customer_id]
            
            # Remove abandonment event for this customer (if it exists)
            # Note: In a more sophisticated implementation, we'd track and remove the event
            
            # Start service for next customer
            servers[event.server_id] = next_customer_id
            next_customer.service_start_time = event.time
            next_customer.wait_time = event.time - next_customer.arrival_time
            
            # Schedule service completion
            completion_time = event.time + next_customer.service_time
            heapq.heappush(event_queue, Event(completion_time, EventType.SERVICE_COMPLETION, 
                                            next_customer_id, event.server_id))
    
    def _handle_service_completion_erlang_s(self, event, queue, active_servers, charging_servers, server_assignments, event_queue):
        """Handle service completion in Erlang-S* system"""
        customer = self.customers[event.customer_id]
        customer.departure_time = event.time
        
        # Remove server from assignments
        if event.server_id in server_assignments:
            del server_assignments[event.server_id]
        else:
            print(f"DEBUG: WARNING - Server {event.server_id} not found in assignments")
        
        #print(f"DEBUG: Service completion for customer {customer.id} by server {event.server_id} at time {event.time:.3f}")
        #print(f"DEBUG: Queue length: {len(queue)}")
        
        # EVERY service completion should have a charging decision
        if self.charging_decision_index < len(self.charging_decisions):
            server_goes_to_charge = bool(self.charging_decisions[self.charging_decision_index])
            server_charging_time = self.charging_times[self.charging_decision_index]
            self.charging_decision_index += 1
            
            #print(f"DEBUG: Server {event.server_id} charging decision: {server_goes_to_charge}")
            
            if server_goes_to_charge:
                # Server goes to charging regardless of queue status
                charging_servers.append(event.server_id)
                #print(f"DEBUG: Server {event.server_id} starts charging for {server_charging_time:.3f} time units")
                
                # Schedule charging completion
                charging_completion_time = event.time + server_charging_time
                customer.charging_time = server_charging_time  # Record charging time for the customer
                heapq.heappush(event_queue, Event(charging_completion_time, EventType.CHARGING_COMPLETION, 
                                                None, event.server_id))
                #print(f"DEBUG: Charging completion scheduled for time {charging_completion_time:.3f}")
                
                # If there are waiting customers, they wait for this server to finish charging
                # OR other available servers can serve them
                
            else:
                # Server doesn't go charging, check if there are waiting customers
                if queue:
                    next_customer_id = queue.pop(0)
                    next_customer = self.customers[next_customer_id]
                    
                    # Use the same server that just finished
                    server_assignments[event.server_id] = next_customer_id
                    next_customer.service_start_time = event.time
                    next_customer.wait_time = event.time - next_customer.arrival_time
                    
                    #print(f"DEBUG: Server {event.server_id} immediately serves next customer {next_customer_id}")
                    
                    # Schedule service completion
                    completion_time = event.time + next_customer.service_time
                    heapq.heappush(event_queue, Event(completion_time, EventType.SERVICE_COMPLETION, 
                                                    next_customer_id, event.server_id))
                else:
                    # No waiting customers, server becomes available
                    active_servers.append(event.server_id)
                    #print(f"DEBUG: Server {event.server_id} becomes immediately available")
        else:
            # Fallback if we run out of pre-generated decisions
            if queue:
                next_customer_id = queue.pop(0)
                next_customer = self.customers[next_customer_id]
                server_assignments[event.server_id] = next_customer_id
                next_customer.service_start_time = event.time
                next_customer.wait_time = event.time - next_customer.arrival_time
                completion_time = event.time + next_customer.service_time
                heapq.heappush(event_queue, Event(completion_time, EventType.SERVICE_COMPLETION, 
                                                next_customer_id, event.server_id))
            else:
                active_servers.append(event.server_id)
                #print(f"DEBUG: Server {event.server_id} becomes available (no more charging decisions)")
        
        #print(f"DEBUG: After service completion - Active: {len(active_servers)}, Charging: {len(charging_servers)}, Occupied: {len(server_assignments)}")
        
    def _handle_abandon(self, event, queue):
        customer_id = event.customer_id
        if customer_id in queue:
            queue.remove(customer_id)
            customer = self.customers[customer_id]
            customer.abandoned = True
            customer.wait_time = event.time - customer.arrival_time
            customer.departure_time = event.time
    
    # def _handle_charging_completion(self, event, active_servers, charging_servers):
    #     server_id = event.server_id
    #     if server_id in charging_servers:
    #         charging_servers.remove(server_id)
    #         active_servers.append(server_id)

# %%
def analyze_and_visualize(customers_a: List[Customer], customers_s: List[Customer], 
                         params: Dict, save_plots: bool = False):
    """Analyze simulation results and create visualizations"""
    
    # Create DataFrames for analysis
    df_a = pd.DataFrame([{
        'customer_id': c.id,
        'arrival_time': c.arrival_time,
        'queue_length_on_arrival': c.queue_length_on_arrival,
        'system_size_on_arrival': c.system_size_on_arrival,
        'servers_available_on_arrival': c.servers_available_on_arrival,
        'wait_time': c.wait_time,
        'service_time': c.service_time,
        'departure_time': c.departure_time,
        'abandoned': c.abandoned,
        'system': 'Erlang-A'
    } for c in customers_a])
    
    df_s = pd.DataFrame([{
        'customer_id': c.id,
        'arrival_time': c.arrival_time,
        'queue_length_on_arrival': c.queue_length_on_arrival,
        'system_size_on_arrival': c.system_size_on_arrival,
        'servers_available_on_arrival': c.servers_available_on_arrival,
        'wait_time': c.wait_time,
        'service_time': c.service_time,
        'departure_time': c.departure_time,
        'abandoned': c.abandoned,
        'system': 'Erlang-S*'
    } for c in customers_s])
    
    df_combined = pd.concat([df_a, df_s], ignore_index=True)
    
    # Print summary statistics
    print("=== SIMULATION RESULTS ===")
    print(f"Parameters: λ={params['lambda']}, μ={params['mu']}, θ={params['theta']}, c={params['c']}")
    print(f"Erlang-S* specific: p={params['p']}, γ={params['gamma']}")
    print("\nERLANG-A QUEUE:")
    print(f"  Average wait time: {df_a['wait_time'].mean():.3f}")
    print(f"  Average queue length on arrival: {df_a['queue_length_on_arrival'].mean():.3f}")
    print(f"  Abandonment rate: {df_a['abandoned'].mean():.3f}")
    print(f"  Average servers available on arrival: {df_a['servers_available_on_arrival'].mean():.3f}")
    
    print("\nERLANG-S* QUEUE:")
    print(f"  Average wait time: {df_s['wait_time'].mean():.3f}")
    print(f"  Average queue length on arrival: {df_s['queue_length_on_arrival'].mean():.3f}")
    print(f"  Abandonment rate: {df_s['abandoned'].mean():.3f}")
    print(f"  Average servers available on arrival: {df_s['servers_available_on_arrival'].mean():.3f}")
    
    # Create comprehensive visualizations
    fig = plt.figure(figsize=(20, 16))
    
    # 1. Wait Time Distributions
    plt.subplot(3, 4, 1)
    non_abandoned_a = df_a[~df_a['abandoned']]['wait_time']
    non_abandoned_s = df_s[~df_s['abandoned']]['wait_time']
    
    plt.hist(non_abandoned_a, alpha=0.7, bins=30, label='Erlang-A', density=True)
    plt.hist(non_abandoned_s, alpha=0.7, bins=30, label='Erlang-S*', density=True)
    plt.xlabel('Wait Time')
    plt.ylabel('Density')
    plt.title('Wait Time Distribution\n(Non-abandoned customers)')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 2. Queue Length on Arrival
    plt.subplot(3, 4, 2)
    queue_lengths_a = df_a['queue_length_on_arrival'].value_counts().sort_index()
    queue_lengths_s = df_s['queue_length_on_arrival'].value_counts().sort_index()
    
    x_pos = np.arange(max(queue_lengths_a.index.max(), queue_lengths_s.index.max()) + 1)
    plt.bar(x_pos - 0.2, [queue_lengths_a.get(i, 0) for i in x_pos], 
            width=0.4, alpha=0.7, label='Erlang-A')
    plt.bar(x_pos + 0.2, [queue_lengths_s.get(i, 0) for i in x_pos], 
            width=0.4, alpha=0.7, label='Erlang-S*')
    plt.xlabel('Queue Length on Arrival')
    plt.ylabel('Frequency')
    plt.title('Queue Length Distribution\n(On Arrival)')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 3. Servers Available on Arrival
    plt.subplot(3, 4, 3)
    servers_a = df_a['servers_available_on_arrival'].value_counts().sort_index()
    servers_s = df_s['servers_available_on_arrival'].value_counts().sort_index()
    
    x_pos = np.arange(params['c'] + 1)
    plt.bar(x_pos - 0.2, [servers_a.get(i, 0) for i in x_pos], 
            width=0.4, alpha=0.7, label='Erlang-A')
    plt.bar(x_pos + 0.2, [servers_s.get(i, 0) for i in x_pos], 
            width=0.4, alpha=0.7, label='Erlang-S*')
    plt.xlabel('Servers Available on Arrival')
    plt.ylabel('Frequency')
    plt.title('Available Servers Distribution\n(On Arrival)')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 4. Abandonment Comparison
    plt.subplot(3, 4, 4)
    abandon_rates = [df_a['abandoned'].mean(), df_s['abandoned'].mean()]
    systems = ['Erlang-A', 'Erlang-S*']
    colors = ['#1f77b4', '#ff7f0e']
    
    bars = plt.bar(systems, abandon_rates, color=colors, alpha=0.7)
    plt.ylabel('Abandonment Rate')
    plt.title('Abandonment Rate Comparison')
    plt.grid(True, alpha=0.3)
    
    # Add value labels on bars
    for bar, rate in zip(bars, abandon_rates):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.001,
                f'{rate:.3f}', ha='center', va='bottom')
    
    # 5. Wait Time Over Time
    plt.subplot(3, 4, 5)
    window_size = max(50, len(customers_a) // 20)
    df_a_sorted = df_a.sort_values('arrival_time')
    df_s_sorted = df_s.sort_values('arrival_time')
    
    wait_time_ma_a = df_a_sorted['wait_time'].rolling(window=window_size, center=True).mean()
    wait_time_ma_s = df_s_sorted['wait_time'].rolling(window=window_size, center=True).mean()
    
    plt.plot(df_a_sorted['arrival_time'], wait_time_ma_a, label='Erlang-A', alpha=0.8)
    plt.plot(df_s_sorted['arrival_time'], wait_time_ma_s, label='Erlang-S*', alpha=0.8)
    plt.xlabel('Arrival Time')
    plt.ylabel('Wait Time (Moving Average)')
    plt.title(f'Wait Time Evolution\n(Moving Average, window={window_size})')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 6. Service Time vs Wait Time Scatter
    plt.subplot(3, 4, 6)
    non_abandoned_a = df_a[~df_a['abandoned']]
    non_abandoned_s = df_s[~df_s['abandoned']]
    
    plt.scatter(non_abandoned_a['service_time'], non_abandoned_a['wait_time'], 
               alpha=0.5, label='Erlang-A', s=20)
    plt.scatter(non_abandoned_s['service_time'], non_abandoned_s['wait_time'], 
               alpha=0.5, label='Erlang-S*', s=20)
    plt.xlabel('Service Time')
    plt.ylabel('Wait Time')
    plt.title('Service Time vs Wait Time')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 7. Queue Length Evolution
    plt.subplot(3, 4, 7)
    plt.plot(df_a_sorted['arrival_time'], 
             df_a_sorted['queue_length_on_arrival'].rolling(window=window_size, center=True).mean(),
             label='Erlang-A', alpha=0.8)
    plt.plot(df_s_sorted['arrival_time'], 
             df_s_sorted['queue_length_on_arrival'].rolling(window=window_size, center=True).mean(),
             label='Erlang-S*', alpha=0.8)
    plt.xlabel('Arrival Time')
    plt.ylabel('Queue Length (Moving Average)')
    plt.title(f'Queue Length Evolution\n(Moving Average, window={window_size})')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 8. Wait Time Box Plot
    plt.subplot(3, 4, 8)
    wait_data = [non_abandoned_a['wait_time'], non_abandoned_s['wait_time']]
    plt.boxplot(wait_data, labels=['Erlang-A', 'Erlang-S*'])
    plt.ylabel('Wait Time')
    plt.title('Wait Time Distribution\n(Box Plot)')
    plt.grid(True, alpha=0.3)
    
    # 9. Probability of Delay (P(Wait > 0))
    plt.subplot(3, 4, 9)
    delay_prob_a = (df_a['wait_time'] > 0).sum() / len(customers_a)
    delay_prob_s = (df_s['wait_time'] > 0).sum() / len(customers_s)
    
    bars = plt.bar(['Erlang-A', 'Erlang-S*'], [delay_prob_a, delay_prob_s], 
                   color=colors, alpha=0.7)
    plt.ylabel('Probability of Delay')
    plt.title('Probability of Delay\nP(Wait Time > 0)')
    plt.grid(True, alpha=0.3)
    
    for bar, prob in zip(bars, [delay_prob_a, delay_prob_s]):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
                f'{prob:.3f}', ha='center', va='bottom')
  
    
    # 10. System Time Distribution (Wait + Service)
    plt.subplot(3, 4, 10)
    system_time_a = non_abandoned_a['wait_time'] + non_abandoned_a['service_time']
    system_time_s = non_abandoned_s['wait_time'] + non_abandoned_s['service_time']
    
    plt.hist(system_time_a, alpha=0.7, bins=30, label='Erlang-A', density=True)
    plt.hist(system_time_s, alpha=0.7, bins=30, label='Erlang-S*', density=True)
    plt.xlabel('System Time (Wait + Service)')
    plt.ylabel('Density')
    plt.title('System Time Distribution')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 11. Utilization Over Time (approximation)
    plt.subplot(3, 4, 11)
    busy_servers_a = params['c'] - df_a_sorted['servers_available_on_arrival']
    busy_servers_s = params['c'] - df_s_sorted['servers_available_on_arrival']
    
    utilization_a = busy_servers_a.rolling(window=window_size, center=True).mean() / params['c']
    utilization_s = busy_servers_s.rolling(window=window_size, center=True).mean() / params['c']
    
    plt.plot(df_a_sorted['arrival_time'], utilization_a, label='Erlang-A', alpha=0.8)
    plt.plot(df_s_sorted['arrival_time'], utilization_s, label='Erlang-S*', alpha=0.8)
    plt.xlabel('Time')
    plt.ylabel('Utilization (approx)')
    plt.title('Server Utilization Over Time')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # 12. Performance Metrics Summary
    plt.subplot(3, 4, 12)
    metrics = ['Avg Wait Time', 'Abandonment Rate', 'Delay Probability', 'Avg Queue Length']
    erlang_a_metrics = [
        df_a['wait_time'].mean(),
        df_a['abandoned'].mean(),
        delay_prob_a,
        df_a['queue_length_on_arrival'].mean()
    ]
    erlang_s_metrics = [
        df_s['wait_time'].mean(),
        df_s['abandoned'].mean(),
        delay_prob_s,
        df_s['queue_length_on_arrival'].mean()
    ]
    
    x = np.arange(len(metrics))
    width = 0.35
    
    plt.bar(x - width/2, erlang_a_metrics, width, label='Erlang-A', alpha=0.7)
    plt.bar(x + width/2, erlang_s_metrics, width, label='Erlang-S*', alpha=0.7)
    
    plt.xlabel('Metrics')
    plt.ylabel('Values')
    plt.title('Performance Metrics Comparison')
    plt.xticks(x, metrics, rotation=45, ha='right')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    
    if save_plots:
        plt.savefig('queue_simulation_analysis.png', dpi=300, bbox_inches='tight')
    
    plt.show()
    
    return df_combined

# %%
def delay_probability(customers_a: List[Customer], customers_s: List[Customer], params: Dict):
    """
    Calculate the probability of delay (waiting time > 0) for all customers.
    
    Args:
        customers_a: List of Customer objects from Erlang-A
        customers_s: List of Customer objects from Erlang-S*
        params: Dictionary of parameters
    
    Returns:
        Tuple of delay probabilities (Erlang-A, Erlang-S*)
    """
    # Create DataFrames for analysis
    df_a = pd.DataFrame([{
        'customer_id': c.id,
        'arrival_time': c.arrival_time,
        'queue_length_on_arrival': c.queue_length_on_arrival,
        'system_size_on_arrival': c.system_size_on_arrival,
        'servers_available_on_arrival': c.servers_available_on_arrival,
        'wait_time': c.wait_time,
        'service_time': c.service_time,
        'departure_time': c.departure_time,
        'abandoned': c.abandoned,
        'system': 'Erlang-A'
    } for c in customers_a])
    
    df_s = pd.DataFrame([{
        'customer_id': c.id,
        'arrival_time': c.arrival_time,
        'queue_length_on_arrival': c.queue_length_on_arrival,
        'system_size_on_arrival': c.system_size_on_arrival,
        'servers_available_on_arrival': c.servers_available_on_arrival,
        'wait_time': c.wait_time,
        'service_time': c.service_time,
        'departure_time': c.departure_time,
        'abandoned': c.abandoned,
        'system': 'Erlang-S*'
    } for c in customers_s])
    
    # colors = ['#1f77b4', '#ff7f0e']
    
    # plt.figure(figsize=(5, 4))
    
    # # FIXED: Calculate delay probability correctly
    delay_prob_a = (df_a['wait_time'] > 0).sum() / len(customers_a)
    delay_prob_s = (df_s['wait_time'] > 0).sum() / len(customers_s)

    abandoned_a = df_a['abandoned'].mean()
    abandoned_s = df_s['abandoned'].mean()
    
    # bars = plt.bar(['Erlang-A', 'Erlang-S*'], [delay_prob_a, delay_prob_s], 
    #                color=colors, alpha=0.7)
    # plt.ylabel('Probability of Delay')
    # plt.title('Probability of Delay\nP(Wait Time > 0)')
    # plt.grid(True, alpha=0.3)
    
    # # Add value labels on bars
    # for bar, prob in zip(bars, [delay_prob_a, delay_prob_s]):
    #     plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
    #             f'{prob:.3f}', ha='center', va='bottom')
    
    # plt.show()
    
    return delay_prob_a, delay_prob_s, abandoned_a, abandoned_s

# %%
if __name__ == "__main__":
    # Simulation parameters
    params = {
        'lambda': 100.0,    # Arrival rate
        'mu': 1,        # Service rate  
        'theta': 1,     # Abandonment rate
        'c': 100,           # Number of servers
        'p': 0.5,         # Probability of going to charge (Erlang-S* only)
        'gamma': 1      # Charging completion rate (Erlang-S* only)
    }
    
    num_customers = int(1000e3)
    
    print("Starting queue simulations...")
    print(f"Simulating {num_customers} customers with parameters:")
    for key, value in params.items():
        print(f"  {key}: {value}")
    
    # Run Erlang-A simulation
    print("\nRunning Erlang-A simulation...")
    sim_a = QueueSimulation(
        num_customers=num_customers,
        lambda_rate=params['lambda'],
        mu_rate=params['mu'],
        theta_rate=params['theta'],
        num_servers=params['c'],
        p_charge=0.0,  # No charging in Erlang-A
        gamma_rate=params['gamma'],
        charging_distribution= 'exponential'
    )
    customers_a = sim_a.simulate_erlang_a()
    
    # Run Erlang-S* simulation
    print("Running Erlang-S* simulation...")
    sim_s = QueueSimulation(
        num_customers=num_customers,
        lambda_rate=params['lambda'],
        mu_rate=params['mu'],
        theta_rate=params['theta'],
        num_servers=params['c'],
        p_charge=params['p'],
        gamma_rate=params['gamma'],
        charging_distribution= 'exponential'
    )
    customers_s = sim_s.simulate_erlang_s()
    
    # Analyze and visualize results
    print("Analyzing results and creating visualizations...")
    #df_results = analyze_and_visualize(customers_a, customers_s, params, save_plots=True)
    df_delay = delay_probability(customers_a, customers_s, params)
    print(df_delay)
    print("\nSimulation completed! Check the generated plots for detailed analysis.")
# Out:
# Starting queue simulations...
# Simulating 1000000 customers with parameters:
#   lambda: 100.0
#   mu: 1
#   theta: 1
#   c: 100
#   p: 0.5
#   gamma: 1
#
# Running Erlang-A simulation...
# Running Erlang-S* simulation...
# Analyzing results and creating visualizations...
# (0.511659, 0.99969, 0.039526, 0.332242)
#
# Simulation completed! Check the generated plots for detailed analysis.

# %%
for customer in customers_a:
    print(customer)
    if customer.id > 100:
        break
# Out:
# Customer(id=0, arrival_time=0.01017014465346594, service_time=0.37304368307483005, patience_time=1.9671344309108598, queue_length_on_arrival=0, servers_available_on_arrival=100, servers_occupied_on_arrival=0, servers_charging_on_arrival=0, system_size_on_arrival=0, wait_time=0.0, service_start_time=0.01017014465346594, departure_time=0.383213827728296, charging_time=0.0, abandoned=False)
# Customer(id=1, arrival_time=0.012818410372705362, service_time=0.9914815262332335, patience_time=1.441875206355855, queue_length_on_arrival=0, servers_available_on_arrival=99, servers_occupied_on_arrival=1, servers_charging_on_arrival=0, system_size_on_arrival=1, wait_time=0.0, service_start_time=0.012818410372705362, departure_time=1.0042999366059389, charging_time=0.0, abandoned=False)
# Customer(id=2, arrival_time=0.024245841486113015, service_time=0.20143648143513243, patience_time=0.030999637623488986, queue_length_on_arrival=0, servers_available_on_arrival=98, servers_occupied_on_arrival=2, servers_charging_on_arrival=0, system_size_on_arrival=2, wait_time=0.0, service_start_time=0.024245841486113015, departure_time=0.22568232292124546, charging_time=0.0, abandoned=False)
# Customer(id=3, arrival_time=0.029215580535379208, service_time=0.6252871706450687, patience_time=2.8682258685325333, queue_length_on_arrival=0, servers_available_on_arrival=97, servers_occupied_on_arrival=3, servers_charging_on_arrival=0, system_size_on_arrival=3, wait_time=0.0, service_start_time=0.029215580535379208, departure_time=0.6545027511804479, charging_time=0.0, abandoned=False)
# Customer(id=4, arrival_time=0.03443174083547207, service_time=0.6886402299244127, patience_time=1.4885398547184245, queue_length_on_arrival=0, servers_available_on_arrival=96, servers_occupied_on_arrival=4, servers_charging_on_arrival=0, system_size_on_arrival=4, wait_time=0.0, service_start_time=0.03443174083547207, departure_time=0.7230719707598847, charging_time=0.0, abandoned=False)
# Customer(id=5, arrival_time=0.06771247968429922, service_time=0.12176196945816452, patience_time=2.9982953626407096, queue_length_on_arrival=0, servers_available_on_arrival=95, servers_occupied_on_arrival=5, servers_charging_on_arrival=0, system_size_on_arrival=5, wait_time=0.0, service_start_time=0.06771247968429922, departure_time=0.18947444914246375, charging_time=0.0, abandoned=False)
# Customer(id=6, arrival_time=0.07531873306185245, service_time=1.8462773840595759, patience_time=1.2167873865460541, queue_length_on_arrival=0, servers_available_on_arrival=94, servers_occupied_on_arrival=6, servers_charging_on_arrival=0, system_size_on_arrival=6, wait_time=0.0, service_start_time=0.07531873306185245, departure_time=1.9215961171214284, charging_time=0.0, abandoned=False)
# Customer(id=7, arrival_time=0.08335208110225877, service_time=1.5813644813237624, patience_time=1.3534900405669485, queue_length_on_arrival=0, servers_available_on_arrival=93, servers_occupied_on_arrival=7, servers_charging_on_arrival=0, system_size_on_arrival=7, wait_time=0.0, service_start_time=0.08335208110225877, departure_time=1.6647165624260212, charging_time=0.0, abandoned=False)
# Customer(id=8, arrival_time=0.08840310484938832, service_time=0.7757443948068837, patience_time=0.4303726460173513, queue_length_on_arrival=0, servers_available_on_arrival=92, servers_occupied_on_arrival=8, servers_charging_on_arrival=0, system_size_on_arrival=8, wait_time=0.0, service_start_time=0.08840310484938832, departure_time=0.864147499656272, charging_time=0.0, abandoned=False)
# Customer(id=9, arrival_time=0.10320795631525288, service_time=0.19037608163373815, patience_time=0.43566449207900226, queue_length_on_arrival=0, servers_available_on_arrival=91, servers_occupied_on_arrival=9, servers_charging_on_arrival=0, system_size_on_arrival=9, wait_time=0.0, service_start_time=0.10320795631525288, departure_time=0.293584037948991, charging_time=0.0, abandoned=False)
# Customer(id=10, arrival_time=0.11127099049839437, service_time=0.21792632248461977, patience_time=0.1425738028845198, queue_length_on_arrival=0, servers_available_on_arrival=90, servers_occupied_on_arrival=10, servers_charging_on_arrival=0, system_size_on_arrival=10, wait_time=0.0, service_start_time=0.11127099049839437, departure_time=0.32919731298301413, charging_time=0.0, abandoned=False)
# Customer(id=11, arrival_time=0.11164742835115947, service_time=0.06088717817421341, patience_time=0.2706485689126627, queue_length_on_arrival=0, servers_available_on_arrival=89, servers_occupied_on_arrival=11, servers_charging_on_arrival=0, system_size_on_arrival=11, wait_time=0.0, service_start_time=0.11164742835115947, departure_time=0.1725346065253729, charging_time=0.0, abandoned=False)
# Customer(id=12, arrival_time=0.12911334600891589, service_time=0.7417255354478913, patience_time=0.43455739874274596, queue_length_on_arrival=0, servers_available_on_arrival=88, servers_occupied_on_arrival=12, servers_charging_on_arrival=0, system_size_on_arrival=12, wait_time=0.0, service_start_time=0.12911334600891589, departure_time=0.8708388814568072, charging_time=0.0, abandoned=False)
# Customer(id=13, arrival_time=0.13276744906244226, service_time=0.7662091584606847, patience_time=3.4008683392523693, queue_length_on_arrival=0, servers_available_on_arrival=87, servers_occupied_on_arrival=13, servers_charging_on_arrival=0, system_size_on_arrival=13, wait_time=0.0, service_start_time=0.13276744906244226, departure_time=0.8989766075231269, charging_time=0.0, abandoned=False)
# Customer(id=14, arrival_time=0.13408164136194006, service_time=1.1953933433644113, patience_time=0.008222086200776302, queue_length_on_arrival=0, servers_available_on_arrival=86, servers_occupied_on_arrival=14, servers_charging_on_arrival=0, system_size_on_arrival=14, wait_time=0.0, service_start_time=0.13408164136194006, departure_time=1.3294749847263514, charging_time=0.0, abandoned=False)
# Customer(id=15, arrival_time=0.16585557053172711, service_time=1.1512374217647257, patience_time=0.0996775435387244, queue_length_on_arrival=0, servers_available_on_arrival=85, servers_occupied_on_arrival=15, servers_charging_on_arrival=0, system_size_on_arrival=15, wait_time=0.0, service_start_time=0.16585557053172711, departure_time=1.3170929922964527, charging_time=0.0, abandoned=False)
# Customer(id=16, arrival_time=0.1875462245750456, service_time=0.9227653914451006, patience_time=0.36191595528125764, queue_length_on_arrival=0, servers_available_on_arrival=85, servers_occupied_on_arrival=15, servers_charging_on_arrival=0, system_size_on_arrival=15, wait_time=0.0, service_start_time=0.1875462245750456, departure_time=1.1103116160201463, charging_time=0.0, abandoned=False)
# Customer(id=17, arrival_time=0.1886947542539559, service_time=1.0965224537474114, patience_time=0.7534525226810345, queue_length_on_arrival=0, servers_available_on_arrival=84, servers_occupied_on_arrival=16, servers_charging_on_arrival=0, system_size_on_arrival=16, wait_time=0.0, service_start_time=0.1886947542539559, departure_time=1.2852172080013673, charging_time=0.0, abandoned=False)
# Customer(id=18, arrival_time=0.1940754865744087, service_time=0.047970805165836364, patience_time=0.9312642230602589, queue_length_on_arrival=0, servers_available_on_arrival=84, servers_occupied_on_arrival=16, servers_charging_on_arrival=0, system_size_on_arrival=16, wait_time=0.0, service_start_time=0.1940754865744087, departure_time=0.24204629174024506, charging_time=0.0, abandoned=False)
# Customer(id=19, arrival_time=0.1988762810151338, service_time=2.626499112726518, patience_time=1.03866033613546, queue_length_on_arrival=0, servers_available_on_arrival=83, servers_occupied_on_arrival=17, servers_charging_on_arrival=0, system_size_on_arrival=17, wait_time=0.0, service_start_time=0.1988762810151338, departure_time=2.8253753937416515, charging_time=0.0, abandoned=False)
# Customer(id=20, arrival_time=0.2026411700567923, service_time=0.3713883100114729, patience_time=1.6659188426484068, queue_length_on_arrival=0, servers_available_on_arrival=82, servers_occupied_on_arrival=18, servers_charging_on_arrival=0, system_size_on_arrival=18, wait_time=0.0, service_start_time=0.2026411700567923, departure_time=0.5740294800682652, charging_time=0.0, abandoned=False)
# Customer(id=21, arrival_time=0.20504904571350002, service_time=0.6396146652698177, patience_time=3.9773619107570175, queue_length_on_arrival=0, servers_available_on_arrival=81, servers_occupied_on_arrival=19, servers_charging_on_arrival=0, system_size_on_arrival=19, wait_time=0.0, service_start_time=0.20504904571350002, departure_time=0.8446637109833177, charging_time=0.0, abandoned=False)
# Customer(id=22, arrival_time=0.2076985249285243, service_time=1.3163548614452398, patience_time=0.20636196647208097, queue_length_on_arrival=0, servers_available_on_arrival=80, servers_occupied_on_arrival=20, servers_charging_on_arrival=0, system_size_on_arrival=20, wait_time=0.0, service_start_time=0.2076985249285243, departure_time=1.5240533863737642, charging_time=0.0, abandoned=False)
# Customer(id=23, arrival_time=0.20834018321275852, service_time=2.920161376807935, patience_time=0.27529972864905383, queue_length_on_arrival=0, servers_available_on_arrival=79, servers_occupied_on_arrival=21, servers_charging_on_arrival=0, system_size_on_arrival=21, wait_time=0.0, service_start_time=0.20834018321275852, departure_time=3.1285015600206934, charging_time=0.0, abandoned=False)
# Customer(id=24, arrival_time=0.2145559200216561, service_time=0.9792560815639024, patience_time=0.3904859346870305, queue_length_on_arrival=0, servers_available_on_arrival=78, servers_occupied_on_arrival=22, servers_charging_on_arrival=0, system_size_on_arrival=22, wait_time=0.0, service_start_time=0.2145559200216561, departure_time=1.1938120015855584, charging_time=0.0, abandoned=False)
# Customer(id=25, arrival_time=0.22162302414464782, service_time=0.33334631301557505, patience_time=0.25116391361589907, queue_length_on_arrival=0, servers_available_on_arrival=77, servers_occupied_on_arrival=23, servers_charging_on_arrival=0, system_size_on_arrival=23, wait_time=0.0, service_start_time=0.22162302414464782, departure_time=0.5549693371602229, charging_time=0.0, abandoned=False)
# Customer(id=26, arrival_time=0.22776362853581142, service_time=0.011424633921135097, patience_time=1.8228061108205933, queue_length_on_arrival=0, servers_available_on_arrival=77, servers_occupied_on_arrival=23, servers_charging_on_arrival=0, system_size_on_arrival=23, wait_time=0.0, service_start_time=0.22776362853581142, departure_time=0.23918826245694652, charging_time=0.0, abandoned=False)
# Customer(id=27, arrival_time=0.23222112054569385, service_time=0.44277352906146084, patience_time=0.19204094120369875, queue_length_on_arrival=0, servers_available_on_arrival=76, servers_occupied_on_arrival=24, servers_charging_on_arrival=0, system_size_on_arrival=24, wait_time=0.0, service_start_time=0.23222112054569385, departure_time=0.6749946496071547, charging_time=0.0, abandoned=False)
# Customer(id=28, arrival_time=0.24330437335233215, service_time=0.6461315812484565, patience_time=0.6791747897356358, queue_length_on_arrival=0, servers_available_on_arrival=77, servers_occupied_on_arrival=23, servers_charging_on_arrival=0, system_size_on_arrival=23, wait_time=0.0, service_start_time=0.24330437335233215, departure_time=0.8894359546007886, charging_time=0.0, abandoned=False)
# Customer(id=29, arrival_time=0.2533219598170264, service_time=0.19261667677348313, patience_time=2.523519755347757, queue_length_on_arrival=0, servers_available_on_arrival=76, servers_occupied_on_arrival=24, servers_charging_on_arrival=0, system_size_on_arrival=24, wait_time=0.0, service_start_time=0.2533219598170264, departure_time=0.4459386365905095, charging_time=0.0, abandoned=False)
# Customer(id=30, arrival_time=0.2753090440476079, service_time=1.399870880994373, patience_time=3.1700291530155487, queue_length_on_arrival=0, servers_available_on_arrival=75, servers_occupied_on_arrival=25, servers_charging_on_arrival=0, system_size_on_arrival=25, wait_time=0.0, service_start_time=0.2753090440476079, departure_time=1.6751799250419808, charging_time=0.0, abandoned=False)
# Customer(id=31, arrival_time=0.280009684634482, service_time=0.9037173623696555, patience_time=2.0048699971519186, queue_length_on_arrival=0, servers_available_on_arrival=74, servers_occupied_on_arrival=26, servers_charging_on_arrival=0, system_size_on_arrival=26, wait_time=0.0, service_start_time=0.280009684634482, departure_time=1.1837270470041374, charging_time=0.0, abandoned=False)
# Customer(id=32, arrival_time=0.28012370921263097, service_time=0.1443645410506446, patience_time=0.03534026539590972, queue_length_on_arrival=0, servers_available_on_arrival=73, servers_occupied_on_arrival=27, servers_charging_on_arrival=0, system_size_on_arrival=27, wait_time=0.0, service_start_time=0.28012370921263097, departure_time=0.4244882502632756, charging_time=0.0, abandoned=False)
# Customer(id=33, arrival_time=0.30560471098221875, service_time=0.25634042532726803, patience_time=0.29484851857934835, queue_length_on_arrival=0, servers_available_on_arrival=73, servers_occupied_on_arrival=27, servers_charging_on_arrival=0, system_size_on_arrival=27, wait_time=0.0, service_start_time=0.30560471098221875, departure_time=0.5619451363094867, charging_time=0.0, abandoned=False)
# Customer(id=34, arrival_time=0.31678071180827105, service_time=0.8728436523336974, patience_time=0.023361395726814126, queue_length_on_arrival=0, servers_available_on_arrival=72, servers_occupied_on_arrival=28, servers_charging_on_arrival=0, system_size_on_arrival=28, wait_time=0.0, service_start_time=0.31678071180827105, departure_time=1.1896243641419684, charging_time=0.0, abandoned=False)
# Customer(id=35, arrival_time=0.3190954531955367, service_time=0.3521439143345981, patience_time=0.1364042335703049, queue_length_on_arrival=0, servers_available_on_arrival=71, servers_occupied_on_arrival=29, servers_charging_on_arrival=0, system_size_on_arrival=29, wait_time=0.0, service_start_time=0.3190954531955367, departure_time=0.6712393675301348, charging_time=0.0, abandoned=False)
# Customer(id=36, arrival_time=0.32252695251540525, service_time=0.496467893838105, patience_time=0.022185144203771427, queue_length_on_arrival=0, servers_available_on_arrival=70, servers_occupied_on_arrival=30, servers_charging_on_arrival=0, system_size_on_arrival=30, wait_time=0.0, service_start_time=0.32252695251540525, departure_time=0.8189948463535103, charging_time=0.0, abandoned=False)
# Customer(id=37, arrival_time=0.32507506581531653, service_time=4.108057909622761, patience_time=0.027812147345410657, queue_length_on_arrival=0, servers_available_on_arrival=69, servers_occupied_on_arrival=31, servers_charging_on_arrival=0, system_size_on_arrival=31, wait_time=0.0, service_start_time=0.32507506581531653, departure_time=4.4331329754380775, charging_time=0.0, abandoned=False)
# Customer(id=38, arrival_time=0.325961531695096, service_time=0.2682919290069785, patience_time=1.6653333727013457, queue_length_on_arrival=0, servers_available_on_arrival=68, servers_occupied_on_arrival=32, servers_charging_on_arrival=0, system_size_on_arrival=32, wait_time=0.0, service_start_time=0.325961531695096, departure_time=0.5942534607020745, charging_time=0.0, abandoned=False)
# Customer(id=39, arrival_time=0.3306942116176743, service_time=1.1298603128966485, patience_time=0.4242996813359769, queue_length_on_arrival=0, servers_available_on_arrival=68, servers_occupied_on_arrival=32, servers_charging_on_arrival=0, system_size_on_arrival=32, wait_time=0.0, service_start_time=0.3306942116176743, departure_time=1.4605545245143228, charging_time=0.0, abandoned=False)
# Customer(id=40, arrival_time=0.34336560899941804, service_time=1.3108634124485556, patience_time=1.9665204960055718, queue_length_on_arrival=0, servers_available_on_arrival=67, servers_occupied_on_arrival=33, servers_charging_on_arrival=0, system_size_on_arrival=33, wait_time=0.0, service_start_time=0.34336560899941804, departure_time=1.6542290214479736, charging_time=0.0, abandoned=False)
# Customer(id=41, arrival_time=0.3517505616245721, service_time=0.9794802726162485, patience_time=3.6999730697915463, queue_length_on_arrival=0, servers_available_on_arrival=66, servers_occupied_on_arrival=34, servers_charging_on_arrival=0, system_size_on_arrival=34, wait_time=0.0, service_start_time=0.3517505616245721, departure_time=1.3312308342408206, charging_time=0.0, abandoned=False)
# Customer(id=42, arrival_time=0.3600018677412474, service_time=2.8045948146489654, patience_time=0.20752660913591314, queue_length_on_arrival=0, servers_available_on_arrival=65, servers_occupied_on_arrival=35, servers_charging_on_arrival=0, system_size_on_arrival=35, wait_time=0.0, service_start_time=0.3600018677412474, departure_time=3.1645966823902127, charging_time=0.0, abandoned=False)
# Customer(id=43, arrival_time=0.3709474141437194, service_time=0.23585287772404312, patience_time=2.01028004607333, queue_length_on_arrival=0, servers_available_on_arrival=64, servers_occupied_on_arrival=36, servers_charging_on_arrival=0, system_size_on_arrival=36, wait_time=0.0, service_start_time=0.3709474141437194, departure_time=0.6068002918677625, charging_time=0.0, abandoned=False)
# Customer(id=44, arrival_time=0.38910585949221943, service_time=0.1191581652078589, patience_time=0.13098599532310545, queue_length_on_arrival=0, servers_available_on_arrival=64, servers_occupied_on_arrival=36, servers_charging_on_arrival=0, system_size_on_arrival=36, wait_time=0.0, service_start_time=0.38910585949221943, departure_time=0.5082640247000784, charging_time=0.0, abandoned=False)
# Customer(id=45, arrival_time=0.39900184054899696, service_time=0.5332214086620147, patience_time=0.29299775795853866, queue_length_on_arrival=0, servers_available_on_arrival=63, servers_occupied_on_arrival=37, servers_charging_on_arrival=0, system_size_on_arrival=37, wait_time=0.0, service_start_time=0.39900184054899696, departure_time=0.9322232492110116, charging_time=0.0, abandoned=False)
# Customer(id=46, arrival_time=0.40790782536430303, service_time=3.4191532542448098, patience_time=0.4186794030318393, queue_length_on_arrival=0, servers_available_on_arrival=62, servers_occupied_on_arrival=38, servers_charging_on_arrival=0, system_size_on_arrival=38, wait_time=0.0, service_start_time=0.40790782536430303, departure_time=3.8270610796091127, charging_time=0.0, abandoned=False)
# Customer(id=47, arrival_time=0.41403463519750855, service_time=0.43060815079060716, patience_time=0.5459972932879531, queue_length_on_arrival=0, servers_available_on_arrival=61, servers_occupied_on_arrival=39, servers_charging_on_arrival=0, system_size_on_arrival=39, wait_time=0.0, service_start_time=0.41403463519750855, departure_time=0.8446427859881157, charging_time=0.0, abandoned=False)
# Customer(id=48, arrival_time=0.42627284623546435, service_time=0.5694292815863824, patience_time=1.0321487497771387, queue_length_on_arrival=0, servers_available_on_arrival=61, servers_occupied_on_arrival=39, servers_charging_on_arrival=0, system_size_on_arrival=39, wait_time=0.0, service_start_time=0.42627284623546435, departure_time=0.9957021278218467, charging_time=0.0, abandoned=False)
# Customer(id=49, arrival_time=0.44103339509402945, service_time=1.3089378471547426, patience_time=0.7497876152088033, queue_length_on_arrival=0, servers_available_on_arrival=60, servers_occupied_on_arrival=40, servers_charging_on_arrival=0, system_size_on_arrival=40, wait_time=0.0, service_start_time=0.44103339509402945, departure_time=1.749971242248772, charging_time=0.0, abandoned=False)
# Customer(id=50, arrival_time=0.4424777257095114, service_time=0.5971550342653545, patience_time=0.006510243726080538, queue_length_on_arrival=0, servers_available_on_arrival=59, servers_occupied_on_arrival=41, servers_charging_on_arrival=0, system_size_on_arrival=41, wait_time=0.0, service_start_time=0.4424777257095114, departure_time=1.0396327599748658, charging_time=0.0, abandoned=False)
# Customer(id=51, arrival_time=0.4562419730874449, service_time=1.5146770828728653, patience_time=0.565853178598211, queue_length_on_arrival=0, servers_available_on_arrival=59, servers_occupied_on_arrival=41, servers_charging_on_arrival=0, system_size_on_arrival=41, wait_time=0.0, service_start_time=0.4562419730874449, departure_time=1.9709190559603103, charging_time=0.0, abandoned=False)
# Customer(id=52, arrival_time=0.4666509120423557, service_time=0.3509460170391001, patience_time=1.830845110657392, queue_length_on_arrival=0, servers_available_on_arrival=58, servers_occupied_on_arrival=42, servers_charging_on_arrival=0, system_size_on_arrival=42, wait_time=0.0, service_start_time=0.4666509120423557, departure_time=0.8175969290814558, charging_time=0.0, abandoned=False)
# Customer(id=53, arrival_time=0.4883357574890934, service_time=0.7120175473218764, patience_time=0.09308927273079791, queue_length_on_arrival=0, servers_available_on_arrival=57, servers_occupied_on_arrival=43, servers_charging_on_arrival=0, system_size_on_arrival=43, wait_time=0.0, service_start_time=0.4883357574890934, departure_time=1.2003533048109698, charging_time=0.0, abandoned=False)
# Customer(id=54, arrival_time=0.4977680606247987, service_time=0.9668681320128479, patience_time=0.2459621843378972, queue_length_on_arrival=0, servers_available_on_arrival=56, servers_occupied_on_arrival=44, servers_charging_on_arrival=0, system_size_on_arrival=44, wait_time=0.0, service_start_time=0.4977680606247987, departure_time=1.4646361926376468, charging_time=0.0, abandoned=False)
# Customer(id=55, arrival_time=0.5028526474177774, service_time=0.5245910345485002, patience_time=0.7703735880695015, queue_length_on_arrival=0, servers_available_on_arrival=55, servers_occupied_on_arrival=45, servers_charging_on_arrival=0, system_size_on_arrival=45, wait_time=0.0, service_start_time=0.5028526474177774, departure_time=1.0274436819662776, charging_time=0.0, abandoned=False)
# Customer(id=56, arrival_time=0.5123951439278227, service_time=0.12439033691966664, patience_time=1.511743947234323, queue_length_on_arrival=0, servers_available_on_arrival=55, servers_occupied_on_arrival=45, servers_charging_on_arrival=0, system_size_on_arrival=45, wait_time=0.0, service_start_time=0.5123951439278227, departure_time=0.6367854808474893, charging_time=0.0, abandoned=False)
# Customer(id=57, arrival_time=0.5454288545289174, service_time=0.5430684704962819, patience_time=1.9832515316893706, queue_length_on_arrival=0, servers_available_on_arrival=54, servers_occupied_on_arrival=46, servers_charging_on_arrival=0, system_size_on_arrival=46, wait_time=0.0, service_start_time=0.5454288545289174, departure_time=1.0884973250251995, charging_time=0.0, abandoned=False)
# Customer(id=58, arrival_time=0.560756569173942, service_time=0.48136638943572685, patience_time=0.13763168761084515, queue_length_on_arrival=0, servers_available_on_arrival=54, servers_occupied_on_arrival=46, servers_charging_on_arrival=0, system_size_on_arrival=46, wait_time=0.0, service_start_time=0.560756569173942, departure_time=1.042122958609669, charging_time=0.0, abandoned=False)
# Customer(id=59, arrival_time=0.5685711667861995, service_time=0.670013928101518, patience_time=0.4534975122734949, queue_length_on_arrival=0, servers_available_on_arrival=54, servers_occupied_on_arrival=46, servers_charging_on_arrival=0, system_size_on_arrival=46, wait_time=0.0, service_start_time=0.5685711667861995, departure_time=1.2385850948877175, charging_time=0.0, abandoned=False)
# Customer(id=60, arrival_time=0.5730732811666758, service_time=2.5154083390533866, patience_time=0.5491515499059985, queue_length_on_arrival=0, servers_available_on_arrival=53, servers_occupied_on_arrival=47, servers_charging_on_arrival=0, system_size_on_arrival=47, wait_time=0.0, service_start_time=0.5730732811666758, departure_time=3.0884816202200622, charging_time=0.0, abandoned=False)
# Customer(id=61, arrival_time=0.5822082351894541, service_time=0.010330040162185937, patience_time=2.374255288074397, queue_length_on_arrival=0, servers_available_on_arrival=53, servers_occupied_on_arrival=47, servers_charging_on_arrival=0, system_size_on_arrival=47, wait_time=0.0, service_start_time=0.5822082351894541, departure_time=0.59253827535164, charging_time=0.0, abandoned=False)
# Customer(id=62, arrival_time=0.5874942489392276, service_time=1.219363064398136, patience_time=0.7111214171530664, queue_length_on_arrival=0, servers_available_on_arrival=52, servers_occupied_on_arrival=48, servers_charging_on_arrival=0, system_size_on_arrival=48, wait_time=0.0, service_start_time=0.5874942489392276, departure_time=1.8068573133373635, charging_time=0.0, abandoned=False)
# Customer(id=63, arrival_time=0.5893242637824496, service_time=0.9135527632604605, patience_time=0.018585413033834805, queue_length_on_arrival=0, servers_available_on_arrival=51, servers_occupied_on_arrival=49, servers_charging_on_arrival=0, system_size_on_arrival=49, wait_time=0.0, service_start_time=0.5893242637824496, departure_time=1.5028770270429102, charging_time=0.0, abandoned=False)
# Customer(id=64, arrival_time=0.5934885438572389, service_time=0.32389937156833254, patience_time=1.5844270925108048, queue_length_on_arrival=0, servers_available_on_arrival=51, servers_occupied_on_arrival=49, servers_charging_on_arrival=0, system_size_on_arrival=49, wait_time=0.0, service_start_time=0.5934885438572389, departure_time=0.9173879154255715, charging_time=0.0, abandoned=False)
# Customer(id=65, arrival_time=0.5970659608508985, service_time=0.7317719421389967, patience_time=1.5743898906743328, queue_length_on_arrival=0, servers_available_on_arrival=51, servers_occupied_on_arrival=49, servers_charging_on_arrival=0, system_size_on_arrival=49, wait_time=0.0, service_start_time=0.5970659608508985, departure_time=1.3288379029898951, charging_time=0.0, abandoned=False)
# Customer(id=66, arrival_time=0.6270376129450146, service_time=1.395766316355567, patience_time=0.7090907857279384, queue_length_on_arrival=0, servers_available_on_arrival=51, servers_occupied_on_arrival=49, servers_charging_on_arrival=0, system_size_on_arrival=49, wait_time=0.0, service_start_time=0.6270376129450146, departure_time=2.0228039293005815, charging_time=0.0, abandoned=False)
# Customer(id=67, arrival_time=0.6321379063580818, service_time=0.7219897414477825, patience_time=0.15508200770654693, queue_length_on_arrival=0, servers_available_on_arrival=50, servers_occupied_on_arrival=50, servers_charging_on_arrival=0, system_size_on_arrival=50, wait_time=0.0, service_start_time=0.6321379063580818, departure_time=1.3541276478058641, charging_time=0.0, abandoned=False)
# Customer(id=68, arrival_time=0.6396217657875057, service_time=1.2053966398693519, patience_time=0.70744245821787, queue_length_on_arrival=0, servers_available_on_arrival=50, servers_occupied_on_arrival=50, servers_charging_on_arrival=0, system_size_on_arrival=50, wait_time=0.0, service_start_time=0.6396217657875057, departure_time=1.8450184056568575, charging_time=0.0, abandoned=False)
# Customer(id=69, arrival_time=0.6485529672150158, service_time=3.27255531612773, patience_time=0.5802431208875852, queue_length_on_arrival=0, servers_available_on_arrival=49, servers_occupied_on_arrival=51, servers_charging_on_arrival=0, system_size_on_arrival=51, wait_time=0.0, service_start_time=0.6485529672150158, departure_time=3.9211082833427455, charging_time=0.0, abandoned=False)
# Customer(id=70, arrival_time=0.648808236141251, service_time=0.6759115831188235, patience_time=0.7502153097270159, queue_length_on_arrival=0, servers_available_on_arrival=48, servers_occupied_on_arrival=52, servers_charging_on_arrival=0, system_size_on_arrival=52, wait_time=0.0, service_start_time=0.648808236141251, departure_time=1.3247198192600744, charging_time=0.0, abandoned=False)
# Customer(id=71, arrival_time=0.6625862948965143, service_time=0.0438318764395053, patience_time=0.611724525641893, queue_length_on_arrival=0, servers_available_on_arrival=48, servers_occupied_on_arrival=52, servers_charging_on_arrival=0, system_size_on_arrival=52, wait_time=0.0, service_start_time=0.6625862948965143, departure_time=0.7064181713360196, charging_time=0.0, abandoned=False)
# Customer(id=72, arrival_time=0.6631240645844363, service_time=1.1928166478330962, patience_time=0.4632331739232105, queue_length_on_arrival=0, servers_available_on_arrival=47, servers_occupied_on_arrival=53, servers_charging_on_arrival=0, system_size_on_arrival=53, wait_time=0.0, service_start_time=0.6631240645844363, departure_time=1.8559407124175324, charging_time=0.0, abandoned=False)
# Customer(id=73, arrival_time=0.6646231407490842, service_time=1.09757789067825, patience_time=0.1594815093100627, queue_length_on_arrival=0, servers_available_on_arrival=46, servers_occupied_on_arrival=54, servers_charging_on_arrival=0, system_size_on_arrival=54, wait_time=0.0, service_start_time=0.6646231407490842, departure_time=1.7622010314273342, charging_time=0.0, abandoned=False)
# Customer(id=74, arrival_time=0.6677012802675754, service_time=1.1021498310806466, patience_time=2.200770719496068, queue_length_on_arrival=0, servers_available_on_arrival=45, servers_occupied_on_arrival=55, servers_charging_on_arrival=0, system_size_on_arrival=55, wait_time=0.0, service_start_time=0.6677012802675754, departure_time=1.7698511113482218, charging_time=0.0, abandoned=False)
# Customer(id=75, arrival_time=0.6719369538021197, service_time=0.6181794950186027, patience_time=0.04999783786164376, queue_length_on_arrival=0, servers_available_on_arrival=45, servers_occupied_on_arrival=55, servers_charging_on_arrival=0, system_size_on_arrival=55, wait_time=0.0, service_start_time=0.6719369538021197, departure_time=1.2901164488207224, charging_time=0.0, abandoned=False)
# Customer(id=76, arrival_time=0.6759123630653753, service_time=0.31772757445703276, patience_time=0.10562710531056765, queue_length_on_arrival=0, servers_available_on_arrival=45, servers_occupied_on_arrival=55, servers_charging_on_arrival=0, system_size_on_arrival=55, wait_time=0.0, service_start_time=0.6759123630653753, departure_time=0.9936399375224081, charging_time=0.0, abandoned=False)
# Customer(id=77, arrival_time=0.6865480090251453, service_time=0.0032701735069185426, patience_time=0.7779252248879108, queue_length_on_arrival=0, servers_available_on_arrival=44, servers_occupied_on_arrival=56, servers_charging_on_arrival=0, system_size_on_arrival=56, wait_time=0.0, service_start_time=0.6865480090251453, departure_time=0.6898181825320638, charging_time=0.0, abandoned=False)
# Customer(id=78, arrival_time=0.6951876552040659, service_time=0.3087808299736853, patience_time=1.0089154319987672, queue_length_on_arrival=0, servers_available_on_arrival=44, servers_occupied_on_arrival=56, servers_charging_on_arrival=0, system_size_on_arrival=56, wait_time=0.0, service_start_time=0.6951876552040659, departure_time=1.0039684851777513, charging_time=0.0, abandoned=False)
# Customer(id=79, arrival_time=0.7027454568948611, service_time=0.07617705905087173, patience_time=0.7109571919575063, queue_length_on_arrival=0, servers_available_on_arrival=43, servers_occupied_on_arrival=57, servers_charging_on_arrival=0, system_size_on_arrival=57, wait_time=0.0, service_start_time=0.7027454568948611, departure_time=0.7789225159457328, charging_time=0.0, abandoned=False)
# Customer(id=80, arrival_time=0.7254950065990361, service_time=0.5991518968978827, patience_time=1.881599753261357, queue_length_on_arrival=0, servers_available_on_arrival=44, servers_occupied_on_arrival=56, servers_charging_on_arrival=0, system_size_on_arrival=56, wait_time=0.0, service_start_time=0.7254950065990361, departure_time=1.3246469034969188, charging_time=0.0, abandoned=False)
# Customer(id=81, arrival_time=0.783352396312156, service_time=2.974594667041459, patience_time=1.5185742748859505, queue_length_on_arrival=0, servers_available_on_arrival=44, servers_occupied_on_arrival=56, servers_charging_on_arrival=0, system_size_on_arrival=56, wait_time=0.0, service_start_time=0.783352396312156, departure_time=3.7579470633536154, charging_time=0.0, abandoned=False)
# Customer(id=82, arrival_time=0.7845441659934925, service_time=0.45247639933718203, patience_time=0.5190602185921112, queue_length_on_arrival=0, servers_available_on_arrival=43, servers_occupied_on_arrival=57, servers_charging_on_arrival=0, system_size_on_arrival=57, wait_time=0.0, service_start_time=0.7845441659934925, departure_time=1.2370205653306745, charging_time=0.0, abandoned=False)
# Customer(id=83, arrival_time=0.7932622178936385, service_time=4.022693183853761, patience_time=0.2839841750389925, queue_length_on_arrival=0, servers_available_on_arrival=42, servers_occupied_on_arrival=58, servers_charging_on_arrival=0, system_size_on_arrival=58, wait_time=0.0, service_start_time=0.7932622178936385, departure_time=4.8159554017473996, charging_time=0.0, abandoned=False)
# Customer(id=84, arrival_time=0.799466074122027, service_time=1.3596549719050806, patience_time=1.1145159590840534, queue_length_on_arrival=0, servers_available_on_arrival=41, servers_occupied_on_arrival=59, servers_charging_on_arrival=0, system_size_on_arrival=59, wait_time=0.0, service_start_time=0.799466074122027, departure_time=2.1591210460271073, charging_time=0.0, abandoned=False)
# Customer(id=85, arrival_time=0.8194469108301172, service_time=1.8467641631576575, patience_time=0.426844732656139, queue_length_on_arrival=0, servers_available_on_arrival=42, servers_occupied_on_arrival=58, servers_charging_on_arrival=0, system_size_on_arrival=58, wait_time=0.0, service_start_time=0.8194469108301172, departure_time=2.6662110739877747, charging_time=0.0, abandoned=False)
# Customer(id=86, arrival_time=0.8199138846397989, service_time=0.8010685859676036, patience_time=1.84784925571906, queue_length_on_arrival=0, servers_available_on_arrival=41, servers_occupied_on_arrival=59, servers_charging_on_arrival=0, system_size_on_arrival=59, wait_time=0.0, service_start_time=0.8199138846397989, departure_time=1.6209824706074025, charging_time=0.0, abandoned=False)
# Customer(id=87, arrival_time=0.8392607487403998, service_time=1.840749908264447, patience_time=0.5654725429639377, queue_length_on_arrival=0, servers_available_on_arrival=40, servers_occupied_on_arrival=60, servers_charging_on_arrival=0, system_size_on_arrival=60, wait_time=0.0, service_start_time=0.8392607487403998, departure_time=2.6800106570048468, charging_time=0.0, abandoned=False)
# Customer(id=88, arrival_time=0.8439747126049344, service_time=0.4950282524620052, patience_time=0.18800951352842069, queue_length_on_arrival=0, servers_available_on_arrival=39, servers_occupied_on_arrival=61, servers_charging_on_arrival=0, system_size_on_arrival=61, wait_time=0.0, service_start_time=0.8439747126049344, departure_time=1.3390029650669395, charging_time=0.0, abandoned=False)
# Customer(id=89, arrival_time=0.8452137578866007, service_time=0.34304929829927283, patience_time=0.03602051382966072, queue_length_on_arrival=0, servers_available_on_arrival=40, servers_occupied_on_arrival=60, servers_charging_on_arrival=0, system_size_on_arrival=60, wait_time=0.0, service_start_time=0.8452137578866007, departure_time=1.1882630561858736, charging_time=0.0, abandoned=False)
# Customer(id=90, arrival_time=0.8711373488802128, service_time=0.48084222404866206, patience_time=0.2984525411901718, queue_length_on_arrival=0, servers_available_on_arrival=41, servers_occupied_on_arrival=59, servers_charging_on_arrival=0, system_size_on_arrival=59, wait_time=0.0, service_start_time=0.8711373488802128, departure_time=1.3519795729288748, charging_time=0.0, abandoned=False)
# Customer(id=91, arrival_time=0.8850819884526601, service_time=0.08838124178688167, patience_time=0.8345571547534157, queue_length_on_arrival=0, servers_available_on_arrival=40, servers_occupied_on_arrival=60, servers_charging_on_arrival=0, system_size_on_arrival=60, wait_time=0.0, service_start_time=0.8850819884526601, departure_time=0.9734632302395417, charging_time=0.0, abandoned=False)
# Customer(id=92, arrival_time=0.886120362116493, service_time=0.1851172332555961, patience_time=0.07841436420161557, queue_length_on_arrival=0, servers_available_on_arrival=39, servers_occupied_on_arrival=61, servers_charging_on_arrival=0, system_size_on_arrival=61, wait_time=0.0, service_start_time=0.886120362116493, departure_time=1.0712375953720892, charging_time=0.0, abandoned=False)
# Customer(id=93, arrival_time=0.8884575926176148, service_time=0.009105727380095319, patience_time=3.7145434047001733, queue_length_on_arrival=0, servers_available_on_arrival=38, servers_occupied_on_arrival=62, servers_charging_on_arrival=0, system_size_on_arrival=62, wait_time=0.0, service_start_time=0.8884575926176148, departure_time=0.8975633199977101, charging_time=0.0, abandoned=False)
# Customer(id=94, arrival_time=0.8897922679738721, service_time=0.3757726283648792, patience_time=0.10352598959451925, queue_length_on_arrival=0, servers_available_on_arrival=38, servers_occupied_on_arrival=62, servers_charging_on_arrival=0, system_size_on_arrival=62, wait_time=0.0, service_start_time=0.8897922679738721, departure_time=1.2655648963387514, charging_time=0.0, abandoned=False)
# Customer(id=95, arrival_time=0.9044456821896372, service_time=1.4694755876525654, patience_time=2.4812455646038183, queue_length_on_arrival=0, servers_available_on_arrival=39, servers_occupied_on_arrival=61, servers_charging_on_arrival=0, system_size_on_arrival=61, wait_time=0.0, service_start_time=0.9044456821896372, departure_time=2.3739212698422025, charging_time=0.0, abandoned=False)
# Customer(id=96, arrival_time=0.9469246148493939, service_time=0.17675678853820123, patience_time=0.10131374593059306, queue_length_on_arrival=0, servers_available_on_arrival=40, servers_occupied_on_arrival=60, servers_charging_on_arrival=0, system_size_on_arrival=60, wait_time=0.0, service_start_time=0.9469246148493939, departure_time=1.1236814033875953, charging_time=0.0, abandoned=False)
# Customer(id=97, arrival_time=0.9469800948604238, service_time=0.7140247218300932, patience_time=0.05914171725061154, queue_length_on_arrival=0, servers_available_on_arrival=39, servers_occupied_on_arrival=61, servers_charging_on_arrival=0, system_size_on_arrival=61, wait_time=0.0, service_start_time=0.9469800948604238, departure_time=1.6610048166905171, charging_time=0.0, abandoned=False)
# Customer(id=98, arrival_time=0.9494362333268943, service_time=0.22922457420344075, patience_time=0.1816089514040382, queue_length_on_arrival=0, servers_available_on_arrival=38, servers_occupied_on_arrival=62, servers_charging_on_arrival=0, system_size_on_arrival=62, wait_time=0.0, service_start_time=0.9494362333268943, departure_time=1.178660807530335, charging_time=0.0, abandoned=False)
# Customer(id=99, arrival_time=0.9535140509095983, service_time=2.796559988793133, patience_time=1.0680258328331615, queue_length_on_arrival=0, servers_available_on_arrival=37, servers_occupied_on_arrival=63, servers_charging_on_arrival=0, system_size_on_arrival=63, wait_time=0.0, service_start_time=0.9535140509095983, departure_time=3.7500740397027315, charging_time=0.0, abandoned=False)
# Customer(id=100, arrival_time=0.957696678790137, service_time=0.18435203413210433, patience_time=0.08298608479526302, queue_length_on_arrival=0, servers_available_on_arrival=36, servers_occupied_on_arrival=64, servers_charging_on_arrival=0, system_size_on_arrival=64, wait_time=0.0, service_start_time=0.957696678790137, departure_time=1.1420487129222412, charging_time=0.0, abandoned=False)
# Customer(id=101, arrival_time=0.9913646830560109, service_time=1.123849052127622, patience_time=1.593987318601457, queue_length_on_arrival=0, servers_available_on_arrival=36, servers_occupied_on_arrival=64, servers_charging_on_arrival=0, system_size_on_arrival=64, wait_time=0.0, service_start_time=0.9913646830560109, departure_time=2.115213735183633, charging_time=0.0, abandoned=False)
